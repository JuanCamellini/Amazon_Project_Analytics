# %% [markdown]
# Parse all the json

# %%
import json, glob
import pandas as pd

# 1. Find all the json files
files = glob.glob('data/api_raw/*.json')
print(files)
# 2. Iterate and parse
rows = []
for file in files:
    
    # extraer categoria y pagina del nombre del archivo
    # parsear JSON
    # iterar search_results
    # extraer campos con .get()
    # appendear dict a rows

# 3. Una sola línea para construir el DataFrame
#df = pd.DataFrame(rows)
# Out:
#   Cell In[1], line 18
#     #df = pd.DataFrame(rows)
#                             ^
# SyntaxError: incomplete input
